# %% [markdown]
# <a href="https://colab.research.google.com/github/adv555/DataScience/blob/main/Hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (1.21.6)

# %%
import numpy as np

# %% [markdown]
# 1. Вкладчик положил 50000 условных единиц на три разных счета в три разных банка. По первому счету выплаты составят 5% годовых, по второму – 7% годовых и по третьему 6% годовых. Известно, что через год вкладчик получил по процентам сумму в 2250 у.е. с первого и второго банка и сумму в 1400 у.е. с первого и третьего банка. Сколько условных единиц он положил на каждый счет изначально?

# %%
A = np.matrix("1, 1, 1; 0.05, 0.07, 0; 0.05, 0, 0.06")
b = np.array([50000,2250,1400])
np.linalg.solve(A,b)
# Out:
# array([10000., 25000., 15000.])

# %% [markdown]
# 2. На складе хранятся мобильные телефоны iPhone 6, iPhone 11, iPhone 12 моделей. Всего 1328 экземпляра. Моделей iPhone 6 на 120 меньше, чем моделей iPhone 11, и на 100 больше, чем моделей iPhone 12. Сколько моделей каждого вида на складе?

# %%
A = np.matrix("1, 1, 1; -1, 1, 0; 1, 0, -1")
b = np.array([1328,120,100])
np.linalg.solve(A,b)
# Out:
# array([436., 556., 336.])

# %% [markdown]
# 3. Составьте каноническое уравнение эллипсоида, проходящего через три точки A,B,C
# ![img3.png](data:image/png;base64,...)
# ---
# Каноническое уравнение эллипсоида в прямоугольной декартовой системе координат имеет вид:
#
# ![img3-1.png](data:image/png;base64,...)

# %%
A = np.array([[3, 0, 3], [6, 0.25, 0], [1, 1/3, 1]])
b = np.array([1,1,1])
l = np.linalg.solve(A,b)
res = 1/l
res
# Out:
# array([12. ,  0.5,  4. ])

# %% [markdown]
# 4. Составьте уравнение параболы проходящей через заданные три точки (1,12), (3,54), (-1,2). Необходимо найти коэффициенты уравнения a,b,c
#
#     `y=a⋅x^2+b⋅x+c`

# %%
A = np.matrix("1,1,1; 9,3,1; 1,-1,1")
b = np.array([12,54,2])
np.linalg.solve(A,b)
# Out:
# array([4., 5., 3.])

# %% [markdown]
# 5. Составьте функцию get_polynom, которая по набору точек вида (x1,y1),(x2,y2),…,(xn+1,yn+1)  будет находить коэффициенты [многочлена](https://ru.wikipedia.org/wiki/%D0%9C%D0%BD%D0%BE%D0%B3%D0%BE%D1%87%D0%BB%D0%B5%D0%BD) ci. Таким образом функция принимает список кортежей с координатами и возвращает набор коэффициентов

# %%
def get_polynom(coords):
    A = np.matrix([[coord[0]**i for i in reversed(range(len(coords)))] for coord in coords])
    print(A)
    # print(len(coords))
    b = np.array([coord[1] for coord in coords])
    
    return np.linalg.solve(A, b)

# %%
get_polynom([(1,12),(3,54),(-1,2)])
# Out:
# [[ 1  1  1]
#  [ 9  3  1]
#  [ 1 -1  1]]
# 3
# array([4., 5., 3.])
